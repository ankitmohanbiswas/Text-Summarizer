# %%
def mul(x:int, y:int)-> int:
    return x*y

# %%
mul(5,6)
# Out:
# 30

# %%
    mul(5,"6")
# Out:
# '66666'

# %%
from beartype import beartype
@beartype
def mul(x:int, y:int)-> int:
    return x*y

# %%
mul(3,"9")
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mul(3,"9")
#
# File <@beartype(__main__.mul) at 0x2df89b94e00>:46, in mul(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.mul() parameter y='9' violates type hint <class 'int'>, as str '9' not instance of int.

# %%
from box.config_box import ConfigBox
dict=ConfigBox({"name":"ankit","value":"null"})
dict.name
# Out:
# 'ankit'

# %%
1+8
# Out:
# 9
